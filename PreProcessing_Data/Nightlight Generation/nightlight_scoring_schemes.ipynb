# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import random
from tqdm import tqdm
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn import pipeline
from sklearn.feature_selection import SelectKBest, f_regression, f_classif, chi2, SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from scipy.stats import pearsonr
from sklearn.metrics import confusion_matrix, classification_report, silhouette_score, f1_score, precision_recall_curve, plot_precision_recall_curve, average_precision_score, auc
from sklearn.svm import SVR, LinearSVR, SVC, LinearSVC
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.kernel_approximation import Nystroem
from sklearn.linear_model import SGDClassifier, SGDRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
from scipy import stats
from keras.layers import Dense
from keras.models import Sequential
from sklearn.metrics import plot_confusion_matrix

# %%
nightlight = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/3.Obtain_Nightlight_Features/computedData/data_2001.pickle', 'rb'))
nightlight_copy = nightlight.copy()
nightlight
# Out:
#             dc_score_none_none  dc_score_none_size  \
# village_id
# 628551.0              0.026978            2.393824
# 628556.0              0.029132            2.535834
# 628553.0              0.027170            2.420391
# 628554.0              0.028957            2.537154
# 628632.0              0.032391            2.767476
# ...                        ...                 ...
# 209407.0              0.041980            1.813834
# 209403.0              0.044548            1.924774
# 209411.0              0.044897            1.939862
# 209412.0              0.046301            2.000527
# 209417.0              0.047494            2.052069
#
#             dc_score_none_size_intensity  dc_score_none_intensity  \
# village_id
# 628551.0                       42.181491                 1.099705
# 628556.0                       44.683828                 1.187529
# 628553.0                       42.649613                 1.107553
# ...

# %%
nightlight = nightlight.to_numpy().astype(float)
print(nightlight)
# Out:
# [[2.69777032e-02 2.39382445e+00 4.21814908e+01 ... 1.05512237e+01
#   4.42912200e+01 6.38462850e+00]
#  [2.91321667e-02 2.53583354e+00 4.46838277e+01 ... 1.05512237e+01
#   4.42912200e+01 6.38462850e+00]
#  [2.71702374e-02 2.42039067e+00 4.26496132e+01 ... 1.05512237e+01
#   4.42912200e+01 6.38462850e+00]
#  ...
#  [4.48972734e-02 1.93986223e+00 5.56222939e+01 ... 6.57317901e+00
#   3.51977145e+01 5.97769155e+00]
#  [4.63013364e-02 2.00052713e+00 5.73617581e+01 ... 6.57317901e+00
#   3.51977145e+01 5.97769155e+00]
#  [4.74942517e-02 2.05206904e+00 5.88396360e+01 ... 6.57317901e+00
#   3.51977145e+01 5.97769155e+00]]

# %%
for i in range(0,21):
  nightlight[:,i] = StandardScaler().fit_transform(nightlight[:,i].reshape(-1,1)).reshape(-1)

nightlight
# Out:
# array([[-0.41009197,  0.84922181,  0.02407574, ..., -0.35199154,
#         -1.66162483,  1.05742802],
#        [-0.39117119,  0.95665311,  0.08092362, ..., -0.35199154,
#         -1.66162483,  1.05742802],
#        [-0.40840111,  0.86931942,  0.03471051, ..., -0.35199154,
#         -1.66162483,  1.05742802],
#        ...,
#        [-0.25271996,  0.50579487,  0.32942278, ..., -1.0145736 ,
#         -1.92993752,  0.78690251],
#        [-0.2403893 ,  0.55168847,  0.36893978, ..., -1.0145736 ,
#         -1.92993752,  0.78690251],
#        [-0.22991296,  0.59068044,  0.40251409, ..., -1.0145736 ,
#         -1.92993752,  0.78690251]])

# %%
final_nightlight = pd.DataFrame(nightlight, index=nightlight_copy.index, columns = nightlight_copy.columns)
final_nightlight
# Out:
#             dc_score_none_none  dc_score_none_size  \
# village_id
# 628551.0             -0.410092            0.849222
# 628556.0             -0.391171            0.956653
# 628553.0             -0.408401            0.869319
# 628554.0             -0.392710            0.957652
# 628632.0             -0.362551            1.131893
# ...                        ...                 ...
# 209407.0             -0.278336            0.410453
# 209403.0             -0.255787            0.494381
# 209411.0             -0.252720            0.505795
# 209412.0             -0.240389            0.551688
# 209417.0             -0.229913            0.590680
#
#             dc_score_none_size_intensity  dc_score_none_intensity  \
# village_id
# 628551.0                        0.024076                 0.285499
# 628556.0                        0.080924                 0.370481
# 628553.0                        0.034711                 0.293094
# ...

# %%
# household_ind_input = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Inputs/Household_Indicators_Input/household_input_2019_combined_new.pickle','rb'))
household_ind_input = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/4.Training_CNN_(Arch_3)/Data/2nd_Level_Regression_Inp/household_input_2001_combined_arch3.pickle', 'rb'))
household_ind_input
# Out:
#             BF_0_OUT_1  BF_0_OUT_2  BF_0_OUT_3  FC_0_OUT_1  FC_0_OUT_2  \
# Village_ID
# 27378         0.546753    0.227011    0.226236    0.559013    0.221311
# 27379         0.499389    0.244926    0.255685    0.536593    0.236775
# 27380         0.512762    0.262645    0.224593    0.558707    0.222080
# 27381         0.361129    0.392448    0.246423    0.540473    0.228022
# 27382         0.476923    0.264620    0.258457    0.546135    0.226884
# ...                ...         ...         ...         ...         ...
# 644661        0.449178    0.260259    0.290563    0.455540    0.263809
# 644682        0.465442    0.254541    0.280016    0.453913    0.248156
# 644683        0.507918    0.236689    0.255393    0.432863    0.259640
# 644687        0.444778    0.267361    0.287861    0.505766    0.241835
# 644693        0.497353    0.246019    0.256628    0.481098    0.243408
#
#             FC_0_OUT_3  MSW_0_OUT_1  MSW_0_OUT_2  MSW_0_OUT_3  BF_1_OUT_1  \
# Village_ID
# ...

# %%
# household_ind_temp = household_ind_input.copy().drop(['dc_score_none_none',
#  'dc_score_none_size',
#  'dc_score_none_size_intensity',
#  'dc_score_log_none',
#  'dc_score_log_size',
#  'dc_score_log_size_intensity',
#  'dc_score_sqrt_none',
#  'dc_score_sqrt_size',
#  'dc_score_sqrt_size_intensity',
#  'dc_score_none_intensity',
#  'dc_score_log_intensity',
#  'dc_score_sqrt_intensity',
#   'dc_score_none_size_only',
#  'dc_score_none_size_intensity_only',
#  'dc_score_none_intensity_only',
#  'dc_score_log_size_only',
#  'dc_score_log_size_intensity_only',
#  'dc_score_log_intensity_only',
#  'dc_score_sqrt_size_only',
#  'dc_score_sqrt_size_intensity_only',
#  'dc_score_sqrt_intensity_only'], axis = 1)

# print(household_ind_temp.columns)
# household_ind_temp

# %%
# final_household = household_ind_temp.join(final_nightlight, how = "inner")

#run for new combined df from hpc
final_household = household_ind_input.join(final_nightlight, how = "inner")

final_household
# Out:
#         BF_0_OUT_1  BF_0_OUT_2  BF_0_OUT_3  FC_0_OUT_1  FC_0_OUT_2  \
# 27378     0.546753    0.227011    0.226236    0.559013    0.221311
# 27379     0.499389    0.244926    0.255685    0.536593    0.236775
# 27380     0.512762    0.262645    0.224593    0.558707    0.222080
# 27381     0.361129    0.392448    0.246423    0.540473    0.228022
# 27382     0.476923    0.264620    0.258457    0.546135    0.226884
# ...            ...         ...         ...         ...         ...
# 644661    0.449178    0.260259    0.290563    0.455540    0.263809
# 644682    0.465442    0.254541    0.280016    0.453913    0.248156
# 644683    0.507918    0.236689    0.255393    0.432863    0.259640
# 644687    0.444778    0.267361    0.287861    0.505766    0.241835
# 644693    0.497353    0.246019    0.256628    0.481098    0.243408
#
#         FC_0_OUT_3  MSW_0_OUT_1  MSW_0_OUT_2  MSW_0_OUT_3  BF_1_OUT_1  ...  \
# 27378     0.219676     0.420802     0.333921     0.245276    0.361129  ...
# ...

# %% [markdown]
# #Add Population

# %%
#Append population
pop_df = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Inputs/Common_Indicators_Inputs_(With_addtional_village_size_and_population)/Input_2001.pickle', 'rb'))
pop_df
# Out:
#             BF_0_OUT_1    BF_0_OUT_2  ...  log_area  sqrt_area
# Village_ID                            ...
# 347135.0      0.996886  2.804913e-03  ...  0.478689   0.273256
# 347136.0      0.803792  1.606696e-01  ...  0.781519   0.626498
# 347137.0      0.999925  6.222542e-06  ...  1.399925   1.508022
# 347138.0      1.000000  8.502429e-08  ...  0.817594   0.671731
# 347139.0      0.999262  4.217611e-09  ...  0.735610   0.569940
# ...                ...           ...  ...       ...        ...
# 597104.0      0.988058  6.845038e-03  ...  0.857623   0.722750
# 597105.0      0.603880  8.308426e-03  ...  0.148134  -0.063231
# 597106.0      0.999546  3.706203e-04  ...  0.359755   0.146639
# 597107.0      0.999879  1.201696e-04  ...  0.787729   0.634234
# 597109.0      0.409275  5.904147e-01  ...  0.481775   0.276629
#
# [340953 rows x 114 columns]

# %%
pop_df.loc[597105.0, :]
# Out:
# BF_0_OUT_1    0.603880
# BF_0_OUT_2    0.008308
# BF_0_OUT_3    0.387811
# FC_0_OUT_1    0.333333
# FC_0_OUT_2    0.333333
#                 ...
# log_hh       -0.898795
# sqrt_hh      -0.913545
# area         -0.225194
# log_area      0.148134
# sqrt_area    -0.063231
# Name: 597105.0, Length: 114, dtype: float64

# %%
pop_df.columns
# Out:
# Index(['BF_0_OUT_1', 'BF_0_OUT_2', 'BF_0_OUT_3', 'FC_0_OUT_1', 'FC_0_OUT_2',
#        'FC_0_OUT_3', 'MSW_0_OUT_1', 'MSW_0_OUT_2', 'MSW_0_OUT_3',
#        'ASSET_0_OUT_1',
#        ...
#        'dc_score_sqrt_intensity_only', 'pop', 'hh', 'log_pop', 'sqrt_pop',
#        'log_hh', 'sqrt_hh', 'area', 'log_area', 'sqrt_area'],
#       dtype='object', length=114)

# %%
final_household = final_household.join(pop_df[['pop', 'hh', 'log_pop', 'sqrt_pop', 'log_hh', 'sqrt_hh']], how="inner")
final_household
# Out:
#         BF_0_OUT_1  BF_0_OUT_2  BF_0_OUT_3  ...  sqrt_pop    log_hh   sqrt_hh
# 27378     0.450654    0.252962    0.296384  ... -0.258938  0.007857 -0.234668
# 27379     0.455719    0.267446    0.276835  ... -0.319619 -0.056165 -0.294303
# 27380     0.433088    0.307435    0.259478  ...  0.976497  0.975670  0.971300
# 27381     0.404751    0.341285    0.253963  ...  0.593897  0.692629  0.551118
# 27382     0.411186    0.296979    0.291835  ...  0.772205  0.707235  0.571260
# ...            ...         ...         ...  ...       ...       ...       ...
# 644661    0.522429    0.235723    0.241848  ...  0.202763  0.833448  0.752116
# 644682    0.470742    0.252283    0.276975  ...  3.410845  2.376310  4.328670
# 644683    0.488841    0.262072    0.249087  ...  1.838625  1.847751  2.756499
# 644687    0.514510    0.236405    0.249086  ...  1.515572  1.724051  2.449161
# 644693    0.532632    0.234279    0.233089  ...  2.731719  2.177037  3.682520
#
# [340953 rows x 125 columns]

# %%
final_household.loc[597105.0, :]
# Out:
# BF_0_OUT_1    0.464499
# BF_0_OUT_2    0.263232
# BF_0_OUT_3    0.272269
# FC_0_OUT_1    0.497883
# FC_0_OUT_2    0.233835
#                 ...
# hh           -0.654007
# log_pop      -0.920857
# sqrt_pop     -0.939694
# log_hh       -0.898795
# sqrt_hh      -0.913545
# Name: 597105, Length: 125, dtype: float64

# %% [markdown]
# #Save Input Dataframe

# %%
final_household
# Out:
#         BF_0_OUT_1  BF_0_OUT_2  BF_0_OUT_3  FC_0_OUT_1  FC_0_OUT_2  \
# 27378     0.546753    0.227011    0.226236    0.559013    0.221311
# 27379     0.499389    0.244926    0.255685    0.536593    0.236775
# 27380     0.512762    0.262645    0.224593    0.558707    0.222080
# 27381     0.361129    0.392448    0.246423    0.540473    0.228022
# 27382     0.476923    0.264620    0.258457    0.546135    0.226884
# ...            ...         ...         ...         ...         ...
# 644661    0.449178    0.260259    0.290563    0.455540    0.263809
# 644682    0.465442    0.254541    0.280016    0.453913    0.248156
# 644683    0.507918    0.236689    0.255393    0.432863    0.259640
# 644687    0.444778    0.267361    0.287861    0.505766    0.241835
# 644693    0.497353    0.246019    0.256628    0.481098    0.243408
#
#         FC_0_OUT_3  MSW_0_OUT_1  MSW_0_OUT_2  MSW_0_OUT_3  BF_1_OUT_1  ...  \
# 27378     0.219676     0.420802     0.333921     0.245276    0.361129  ...
# ...

# %%
# pickle.dump(final_household, open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Inputs/Household_Indicators_Input/household_input_2019_combined_new.pickle', 'wb'))
pickle.dump(final_household, open('/content/drive/MyDrive/Scripts_and_Data_Transfer/4.Training_CNN_(Arch_3)/Data/2nd_Level_Regression_Inp/household_input_2001_combined_arch3.pickle', 'wb'))

# %%
# fin = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Inputs/Household_Indicators_Input/household_input_2011_arch3_viirs_popAdd.pickle', 'rb'))
# fin.equals(final_household)

# %% [markdown]
# #Rough work

# %%
def scaling(nightlight) : 
  nightlight_copy = nightlight.copy()
  nightlight = nightlight.to_numpy().astype(float)
  
  for i in range(0,21):
    nightlight[:,i] = StandardScaler().fit_transform(nightlight[:,i].reshape(-1,1)).reshape(-1)

  final_nightlight = pd.DataFrame(nightlight, index=nightlight_copy.index, columns = nightlight_copy.columns)
  return final_nightlight

# %%
n_dmsp = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/3.Obtain_Nightlight_Features/computedData/result_dmsp_2011.pickle', 'rb'))
n_viirs = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/3.Obtain_Nightlight_Features/computedData/result_viirs_2012.pickle', 'rb'))
n = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Inputs/Household_Indicators_Input/household_input_2011.pickle','rb'))

# %%
n_dmsp = scaling(n_dmsp)
n_viirs = scaling(n_viirs)
n = n.loc[:, ['dc_score_none_none',
 'dc_score_none_size',
 'dc_score_none_size_intensity',
 'dc_score_log_none',
 'dc_score_log_size',
 'dc_score_log_size_intensity',
 'dc_score_sqrt_none',
 'dc_score_sqrt_size',
 'dc_score_sqrt_size_intensity',
 'dc_score_none_intensity',
 'dc_score_log_intensity',
 'dc_score_sqrt_intensity',
  'dc_score_none_size_only',
 'dc_score_none_size_intensity_only',
 'dc_score_none_intensity_only',
 'dc_score_log_size_only',
 'dc_score_log_size_intensity_only',
 'dc_score_log_intensity_only',
 'dc_score_sqrt_size_only',
 'dc_score_sqrt_size_intensity_only',
 'dc_score_sqrt_intensity_only']]

# %%
n_dmsp.head()
# Out:
#             dc_score_none_none  ...  dc_score_sqrt_intensity_only
# village_id                      ...
# 628551.0              0.039635  ...                      0.864296
# 628556.0             -0.022599  ...                      0.864296
# 628553.0             -0.081093  ...                      0.864296
# 628554.0             -0.045636  ...                      0.864296
# 628632.0             -0.160902  ...                      0.864296
#
# [5 rows x 21 columns]

# %%
n.loc[[628551.0, 628556.0, 628553.0, 628554.0, 628632.0], :]
# Out:
#             dc_score_none_none  ...  dc_score_sqrt_intensity_only
# Village_ID                      ...
# 628551.0              0.361315  ...                     -0.111719
# 628556.0             -0.006723  ...                     -0.111719
# 628553.0              0.192857  ...                     -0.111719
# 628554.0              0.052272  ...                     -0.111719
# 628632.0             -0.269763  ...                     -0.111719
#
# [5 rows x 21 columns]

# %%
n_viirs.head()
# Out:
#             dc_score_none_none  ...  dc_score_sqrt_intensity_only
# village_id                      ...
# 628551.0              0.567367  ...                     -1.650982
# 628556.0              0.382805  ...                     -1.634163
# 628553.0              0.547191  ...                     -1.626218
# 628554.0              0.667196  ...                     -1.634163
# 628632.0              0.069473  ...                     -1.634163
#
# [5 rows x 21 columns]

# %%
df1 = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/4.Training_CNN_(Arch_3)/Data/2nd_Level_Regression_Inp/final_household_ind_reg_input_2011_softmax_ind_StandardScaler_asset_additionalFeatures.pickle', 'rb'))
df = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/4.Training_CNN_(Arch_3)/Data/2nd_Level_Regression_Inp/household_input_2011_combined_arch3.pickle', 'rb'))

# %%
bf_rud = df1 = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/4.Training_CNN_(Arch_3)/Data/CNN_regression_prediction_pickle_files/BF_RUD_new.pickle', 'rb'))
bf_df = pd.DataFrame.from_dict(bf_rud, orient='index', columns=['foo'])
len(bf_df)
# Out:
# 340953

# %%
bf_rud_old = df1 = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/4.Training_CNN_(Arch_3)/Data/CNN_regression_prediction_pickle_files/BF_RUD.pickle', 'rb'))
bf_df_old = pd.DataFrame.from_dict(bf_rud_old, orient='index', columns=['foo'])
len(bf_df_old)
# Out:
# 340953

# %%
bf_df_old = bf_df_old.filter(items = bf_df.index, axis = 0)
len(bf_df_old)
# Out:
# 340953

# %%
bf_df_old.head()
# Out:
#              foo
# 103389  0.921681
# 621411  0.899736
# 601581  0.914120
# 73565   0.899042
# 173112  0.739097

# %%
bf_df.head()
# Out:
#              foo
# 103389  0.921681
# 621411  0.899736
# 601581  0.914120
# 73565   0.899042
# 173112  0.739097

# %%
(bf_df == bf_df_old)
# Out:
#           foo
# 103389  False
# 621411   True
# 601581   True
# 73565   False
# 173112  False
# ...       ...
# 445975   True
# 591127  False
# 238631   True
# 76046    True
# 73435    True
#
# [340953 rows x 1 columns]

# %%
print(float(bf_df.loc[103389, :]), float(bf_df_old.loc[103389, :]))
# Out:
# 0.9216812252998352 0.92168128490448

# %% [markdown]
# #Last dataframe

# %%
df2 = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Inputs/Household_Indicators_Input/household_input_2011.pickle','rb'))
df1 = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Inputs/Household_Indicators_Input/household_input_2011_viirs_popAdded.pickle','rb'))

# %%
df2
# Out:
#             BF_0_OUT_1  ...  dc_score_sqrt_intensity_only
# Village_ID              ...
# 347135.0      0.996886  ...                      2.086867
# 347136.0      0.803792  ...                      2.086867
# 347137.0      0.999925  ...                      2.086867
# 347138.0      1.000000  ...                      2.086867
# 347139.0      0.999262  ...                      2.086867
# ...                ...  ...                           ...
# 597104.0      0.988058  ...                     -0.111719
# 597105.0      0.603880  ...                     -0.111719
# 597106.0      0.999546  ...                     -0.111719
# 597107.0      0.999879  ...                     -0.111719
# 597109.0      0.409275  ...                     -0.111719
#
# [340953 rows x 105 columns]

# %%
df1
# Out:
#         BF_0_OUT_1  BF_0_OUT_2  BF_0_OUT_3  ...  sqrt_pop    log_hh   sqrt_hh
# 27378     0.053910    0.939236    0.006854  ... -0.258938  0.007857 -0.234668
# 27379     0.020868    0.978828    0.000304  ... -0.319619 -0.056165 -0.294303
# 27380     0.162426    0.836869    0.000704  ...  0.976497  0.975670  0.971300
# 27381     0.047692    0.879542    0.072766  ...  0.593897  0.692629  0.551118
# 27382     0.764473    0.017324    0.218203  ...  0.772205  0.707235  0.571260
# ...            ...         ...         ...  ...       ...       ...       ...
# 644661    0.003038    0.996960    0.000002  ...  0.202763  0.833448  0.752116
# 644682    0.020880    0.000908    0.978212  ...  3.410845  2.376310  4.328670
# 644683    0.015891    0.014879    0.969230  ...  1.838625  1.847751  2.756499
# 644687    0.995348    0.000146    0.004507  ...  1.515572  1.724051  2.449161
# 644693    0.999980    0.000012    0.000008  ...  2.731719  2.177037  3.682520
#
# [340953 rows x 132 columns]

# %%
list(df1.columns)
# Out:
# ['BF_0_OUT_1',
#  'BF_0_OUT_2',
#  'BF_0_OUT_3',
#  'FC_0_OUT_1',
#  'FC_0_OUT_2',
#  'FC_0_OUT_3',
#  'MSW_0_OUT_1',
#  'MSW_0_OUT_2',
#  'MSW_0_OUT_3',
#  'ASSET_0_OUT_1',
#  'ASSET_0_OUT_2',
#  'ASSET_0_OUT_3',
#  'LIT_0_OUT_1',
#  'LIT_0_OUT_2',
#  'LIT_0_OUT_3',
#  'BF_1_OUT_1',
#  'BF_1_OUT_2',
#  'BF_1_OUT_3',
#  'FC_1_OUT_1',
#  'FC_1_OUT_2',
#  'FC_1_OUT_3',
#  'MSW_1_OUT_1',
#  'MSW_1_OUT_2',
#  'MSW_1_OUT_3',
#  'ASSET_1_OUT_1',
#  'ASSET_1_OUT_2',
#  'ASSET_1_OUT_3',
#  'LIT_1_OUT_1',
#  'LIT_1_OUT_2',
#  'LIT_1_OUT_3',
#  'BF_2_OUT_1',
#  'BF_2_OUT_2',
#  'BF_2_OUT_3',
#  'FC_2_OUT_1',
#  'FC_2_OUT_2',
#  'FC_2_OUT_3',
#  'MSW_2_OUT_1',
#  'MSW_2_OUT_2',
#  'MSW_2_OUT_3',
#  'ASSET_2_OUT_1',
#  'ASSET_2_OUT_2',
#  'ASSET_2_OUT_3',
#  'LIT_2_OUT_1',
#  'LIT_2_OUT_2',
#  'LIT_2_OUT_3',
#  'BF_3_OUT_1',
#  'BF_3_OUT_2',
#  'BF_3_OUT_3',
#  'FC_3_OUT_1',
#  'FC_3_OUT_2',
#  'FC_3_OUT_3',
#  'MSW_3_OUT_1',
#  'MSW_3_OUT_2',
#  'MSW_3_OUT_3',
#  'ASSET_3_OUT_1',
# ...

# %%
# df1_temp = df1.copy().drop(['dc_score_none_none',
#  'dc_score_none_size',
#  'dc_score_none_size_intensity',
#  'dc_score_log_none',
#  'dc_score_log_size',
#  'dc_score_log_size_intensity',
#  'dc_score_sqrt_none',
#  'dc_score_sqrt_size',
#  'dc_score_sqrt_size_intensity',
#  'dc_score_none_intensity',
#  'dc_score_log_intensity',
#  'dc_score_sqrt_intensity',
#   'dc_score_none_size_only',
#  'dc_score_none_size_intensity_only',
#  'dc_score_none_intensity_only',
#  'dc_score_log_size_only',
#  'dc_score_log_size_intensity_only',
#  'dc_score_log_intensity_only',
#  'dc_score_sqrt_size_only',
#  'dc_score_sqrt_size_intensity_only',
#  'dc_score_sqrt_intensity_only'], axis = 1)

# print(list(df1.columns))
# df1

df1_temp = df1.copy()[['BF_0_OUT_1',
 'BF_0_OUT_2',
 'BF_0_OUT_3',
 'FC_0_OUT_1',
 'FC_0_OUT_2',
 'FC_0_OUT_3',
 'MSW_0_OUT_1',
 'MSW_0_OUT_2',
 'MSW_0_OUT_3',
 'ASSET_0_OUT_1',
 'ASSET_0_OUT_2',
 'ASSET_0_OUT_3',
 'LIT_0_OUT_1',
 'LIT_0_OUT_2',
 'LIT_0_OUT_3',
 'BF_1_OUT_1',
 'BF_1_OUT_2',
 'BF_1_OUT_3',
 'FC_1_OUT_1',
 'FC_1_OUT_2',
 'FC_1_OUT_3',
 'MSW_1_OUT_1',
 'MSW_1_OUT_2',
 'MSW_1_OUT_3',
 'ASSET_1_OUT_1',
 'ASSET_1_OUT_2',
 'ASSET_1_OUT_3',
 'LIT_1_OUT_1',
 'LIT_1_OUT_2',
 'LIT_1_OUT_3',
 'BF_2_OUT_1',
 'BF_2_OUT_2',
 'BF_2_OUT_3',
 'FC_2_OUT_1',
 'FC_2_OUT_2',
 'FC_2_OUT_3',
 'MSW_2_OUT_1',
 'MSW_2_OUT_2',
 'MSW_2_OUT_3',
 'ASSET_2_OUT_1',
 'ASSET_2_OUT_2',
 'ASSET_2_OUT_3',
 'LIT_2_OUT_1',
 'LIT_2_OUT_2',
 'LIT_2_OUT_3',
 'BF_3_OUT_1',
 'BF_3_OUT_2',
 'BF_3_OUT_3',
 'FC_3_OUT_1',
 'FC_3_OUT_2',
 'FC_3_OUT_3',
 'MSW_3_OUT_1',
 'MSW_3_OUT_2',
 'MSW_3_OUT_3',
 'ASSET_3_OUT_1',
 'ASSET_3_OUT_2',
 'ASSET_3_OUT_3',
 'LIT_3_OUT_1',
 'LIT_3_OUT_2',
 'LIT_3_OUT_3',
 'BF_4_OUT_1',
 'BF_4_OUT_2',
 'BF_4_OUT_3',
 'FC_4_OUT_1',
 'FC_4_OUT_2',
 'FC_4_OUT_3',
 'MSW_4_OUT_1',
 'MSW_4_OUT_2',
 'MSW_4_OUT_3',
 'ASSET_4_OUT_1',
 'ASSET_4_OUT_2',
 'ASSET_4_OUT_3',
 'LIT_4_OUT_1',
 'LIT_4_OUT_2',
 'LIT_4_OUT_3',
 'BF_5_OUT_1',
 'BF_5_OUT_2',
 'BF_5_OUT_3',
 'FC_5_OUT_1',
 'FC_5_OUT_2',
 'FC_5_OUT_3',
 'MSW_5_OUT_1',
 'MSW_5_OUT_2',
 'MSW_5_OUT_3',
 'ASSET_5_OUT_1',
 'ASSET_5_OUT_2',
 'ASSET_5_OUT_3',
 'LIT_5_OUT_1',
 'LIT_5_OUT_2',
 'LIT_5_OUT_3',
 'BF_N_OUT_1',
 'BF_N_OUT_2',
 'BF_N_OUT_3',
 'FC_N_OUT_1',
 'FC_N_OUT_2',
 'FC_N_OUT_3',
 'MSW_N_OUT_1',
 'MSW_N_OUT_2',
 'MSW_N_OUT_3',
 'ASSET_N_OUT_1',
 'ASSET_N_OUT_2',
 'ASSET_N_OUT_3',
 'LIT_N_OUT_1',
 'LIT_N_OUT_2',
 'LIT_N_OUT_3']]

# %%
fin = df1_temp.join(df2[['dc_score_none_none',
 'dc_score_none_size',
 'dc_score_none_size_intensity',
 'dc_score_log_none',
 'dc_score_log_size',
 'dc_score_log_size_intensity',
 'dc_score_sqrt_none',
 'dc_score_sqrt_size',
 'dc_score_sqrt_size_intensity',
 'dc_score_none_intensity',
 'dc_score_log_intensity',
 'dc_score_sqrt_intensity',
  'dc_score_none_size_only',
 'dc_score_none_size_intensity_only',
 'dc_score_none_intensity_only',
 'dc_score_log_size_only',
 'dc_score_log_size_intensity_only',
 'dc_score_log_intensity_only',
 'dc_score_sqrt_size_only',
 'dc_score_sqrt_size_intensity_only',
 'dc_score_sqrt_intensity_only']], how = "inner")

# %%
fin
# Out:
#         BF_0_OUT_1  ...  dc_score_sqrt_intensity_only
# 27378     0.053910  ...                     -1.354817
# 27379     0.020868  ...                     -1.354817
# 27380     0.162426  ...                     -1.354817
# 27381     0.047692  ...                     -1.354817
# 27382     0.764473  ...                     -1.354817
# ...            ...  ...                           ...
# 644661    0.003038  ...                     -1.372226
# 644682    0.020880  ...                     -1.333877
# 644683    0.015891  ...                     -1.333877
# 644687    0.995348  ...                     -1.333877
# 644693    0.999980  ...                     -1.333877
#
# [340953 rows x 126 columns]

# %%
df2.loc[27378, :]
# Out:
# BF_0_OUT_1                           0.333333
# BF_0_OUT_2                           0.333333
# BF_0_OUT_3                           0.333333
# FC_0_OUT_1                           0.809554
# FC_0_OUT_2                           0.009099
#                                        ...
# dc_score_log_size_intensity_only     0.721405
# dc_score_log_intensity_only         -1.820167
# dc_score_sqrt_size_only             -1.154310
# dc_score_sqrt_size_intensity_only    0.827574
# dc_score_sqrt_intensity_only        -1.354817
# Name: 27378.0, Length: 105, dtype: float64

# %%
fin.loc[27378, :]
# Out:
# BF_0_OUT_1                           0.053910
# BF_0_OUT_2                           0.939236
# BF_0_OUT_3                           0.006854
# FC_0_OUT_1                           0.809554
# FC_0_OUT_2                           0.009099
#                                        ...
# dc_score_log_size_intensity_only     0.721405
# dc_score_log_intensity_only         -1.820167
# dc_score_sqrt_size_only             -1.154310
# dc_score_sqrt_size_intensity_only    0.827574
# dc_score_sqrt_intensity_only        -1.354817
# Name: 27378, Length: 126, dtype: float64

# %%
df2 = df2.filter(items = fin.index, axis = 0)
# Out:
#             dc_score_none_none  ...  dc_score_sqrt_intensity_only
# Village_ID                      ...
# 27378                 0.407427  ...                     -1.354817
# 27379                 0.658831  ...                     -1.354817
# 27380                 0.080571  ...                     -1.354817
# 27381                 0.309724  ...                     -1.354817
# 27382                 0.308561  ...                     -1.354817
# ...                        ...  ...                           ...
# 644661                1.712385  ...                     -1.372226
# 644682                1.850601  ...                     -1.333877
# 644683                1.240612  ...                     -1.333877
# 644687                0.535717  ...                     -1.333877
# 644693                0.054244  ...                     -1.333877
#
# [340953 rows x 21 columns]

# %%
pickle.dump(fin, open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Inputs/Household_Indicators_Input/inp_2011', 'wb'))
