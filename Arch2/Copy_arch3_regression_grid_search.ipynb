# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import random
from tqdm import tqdm
import tqdm

from sklearn.feature_selection import SelectKBest, f_regression, f_classif, chi2, SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from scipy.stats import pearsonr
from sklearn.metrics import confusion_matrix
from sklearn.svm import SVR, LinearSVR, SVC, LinearSVC
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.kernel_approximation import Nystroem
from sklearn.linear_model import SGDClassifier, SGDRegressor
from sklearn.neural_network import MLPClassifier, MLPRegressor
from scipy import stats
from keras.layers import Dense
from keras.models import Sequential
from sklearn.impute import SimpleImputer
import os
import sys
import tqdm

# %%
# cd drive/MyDrive/Scripts_and_Data_Transfer/

# %%
ls 4.Training_CNN_\(Arch_3\)/Models/2nd_level_models/trial_models
# Out:
# ls: cannot access '4.Training_CNN_(Arch_3)/Models/2nd_level_models/trial_models': No such file or directory

# %% [markdown]
# #Make Train and Test data

# %%
# len(fc_train)

# %%
fc_train = pickle.load(open('drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/6.Classification_Performance_on_Household_Indicators/Indicator_Classes/Train(According_to_Arch_1)/lit_lvls.pickle','rb'))
fc_val = pickle.load(open('drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/6.Classification_Performance_on_Household_Indicators/Indicator_Classes/Val(According_to_Arch_1)/lit_lvls.pickle','rb'))
print(len(fc_train), len(fc_val))
fc = fc_train.copy()
fc.update(fc_val)
len(fc)
print(type(fc))
fc_out = pd.DataFrame.from_dict(fc, orient='index', columns=['LEVEL'])

fc_out
# Out:
# 269377 67623
# <class 'dict'>
#           LEVEL
# 347135.0    1.0
# 347136.0    2.0
# 347138.0    2.0
# 347139.0    2.0
# 347140.0    2.0
# ...         ...
# 587760.0    3.0
# 545693.0    3.0
# 131993.0    3.0
# 520222.0    3.0
# 380288.0    3.0
#
# [337000 rows x 1 columns]

# %%
IN = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Inputs/Household_Indicators_Input/household_input_2011_combined_new.pickle', 'rb'))
# IN1 = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Inputs/Household_Indicators_Input/household_input_2011.pickle', 'rb'))
a = IN.copy()
# OUT = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Outputs/2011/Percentage_of_Households_LitMslAdded.pickle','rb'))
OUT = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Outputs/2011/Percentage_of_Households_LitMslAdded.pickle','rb'))

# %%
non_outliers = set(fc_out.index)
total = set(IN.index)
outliers = total.difference(non_outliers)
len(outliers)
# Out:
# 3953

# %%
# IN1[['ASSET_0_OUT_1',	'ASSET_0_OUT_2',	'ASSET_0_OUT_3']].filter(items = non_outliers, axis = 0)

# %%
# IN[['ASSET_0_OUT_1',	'ASSET_0_OUT_2',	'ASSET_0_OUT_3']].filter(items = non_outliers, axis = 0)

# %%
# temp_IN = IN[['ASSET_0_OUT_1',	'ASSET_0_OUT_2',	'ASSET_0_OUT_3']].filter(items = outliers, axis = 0)
# temp_IN

# %%
# temp_IN.describe()

# %%
# IN = IN.filter(items = fc_out.index, axis = 0)
# OUT = OUT.filter(items = IN.index, axis = 0)
# IN = IN.filter(items = OUT.index, axis = 0)

# %%
# set(a.index).difference(set(IN.index))
# 528644.0,
# 528646.0,
# 528648.0,
# 528649.0,
# 625362.0

print(list(a.loc[625362.0, :]))
# Out:
# [0.06723308265295386, 0.8605205183550558, 0.07224639899199031, 0.014179853902865537, 7.726418058319911e-05, 0.9857428819165512, 0.034991531994040245, 0.20070872253505306, 0.7642997454709067, 0.003614564974706098, 0.057794545100099785, 0.938590889925194, 0.003885893419024161, 0.6232629018828293, 0.3728512046981465, 0.0010600110329165844, 0.010196372455121672, 0.9887436165119617, 0.8900028628069525, 0.06686623152839188, 0.0431309056646556, 0.034277364018429964, 0.06825550648811449, 0.8974671294934555, 0.003918932975775511, 0.04648235536301075, 0.9495987116612137, 0.018549378881655657, 0.4247139327960773, 0.5567366883222671, 2.1864550471647583e-05, 0.999976928742817, 1.206706711339402e-06, 0.7477168796447926, 0.0013488758008735051, 0.2509342445543339, 0.007524769639648869, 0.15534059023642105, 0.83713464012393, 0.0035156750080153694, 0.02663836624981632, 0.9698459587421683, 0.018882433060655623, 0.5405491188530315, 0.44056844808631296, 0.033125097107654496, 0.11067343578346919, 0.856201
# ...

# %%
IN
# Out:
#         BF_0_OUT_1  BF_0_OUT_2  BF_0_OUT_3  ...  sqrt_pop    log_hh   sqrt_hh
# 27378     0.053910    0.939236    0.006854  ... -0.286324  0.007857 -0.234668
# 27379     0.020868    0.978828    0.000304  ... -0.359097 -0.056165 -0.294303
# 27380     0.162426    0.836869    0.000704  ...  0.916267  0.975670  0.971300
# 27381     0.047692    0.879542    0.072766  ...  0.536375  0.692629  0.551118
# 27382     0.764473    0.017324    0.218203  ...  0.756620  0.707235  0.571260
# ...            ...         ...         ...  ...       ...       ...       ...
# 644661    0.003038    0.996960    0.000002  ...  0.102866  0.833448  0.752116
# 644682    0.020880    0.000908    0.978212  ...  3.220821  2.376310  4.328670
# 644683    0.015891    0.014879    0.969230  ...  1.676138  1.847751  2.756499
# 644687    0.995348    0.000146    0.004507  ...  1.374471  1.724051  2.449161
# 644693    0.999980    0.000012    0.000008  ...  2.546358  2.177037  3.682520
#
# [340953 rows x 132 columns]

# %%
OUT
# Out:
#           BF_RUD  BF_INT  BF_ADV  CHH_RUD  ...  MSL_RUD  MSL_INT  MSL_ADV        LIT
# 347135.0    99.2     0.0     0.8     47.0  ...      0.0    100.0      0.0  41.255605
# 347136.0   100.0     0.0     0.0     66.2  ...      0.0    100.0      0.0  51.055276
# 347137.0    98.3     0.0     1.5      5.0  ...      0.0     98.7      1.3  45.053533
# 347138.0    98.8     0.0     1.2     42.5  ...      0.0     77.7     22.3  50.786948
# 347139.0    97.7     2.1     0.2      6.6  ...      0.0    100.0      0.0  52.052307
# ...          ...     ...     ...      ...  ...      ...      ...      ...        ...
# 597104.0    96.1     0.4     3.4     69.8  ...      0.4     12.8     86.8  60.180542
# 597105.0   100.0     0.0     0.0    100.0  ...      0.0      0.0    100.0  72.413793
# 597106.0    99.0     0.0     1.0     79.2  ...      0.0      9.4     90.6  64.454976
# 597107.0   100.0     0.0     0.0     44.0  ...      0.0      4.0     96.0  63.456790
# ...

# %%
OUT = OUT.filter(items = IN.index, axis = 0)
OUT
# Out:
#         BF_RUD  BF_INT  BF_ADV  CHH_RUD  ...  MSL_RUD  MSL_INT  MSL_ADV        LIT
# 27378     69.4     0.0    30.6     53.6  ...      1.1      1.6     97.3  67.018779
# 27379     95.9     0.0     4.2     15.4  ...      0.0      9.5     90.5  71.282051
# 27380     70.8     0.0    29.0     87.4  ...      1.0      4.6     94.4  71.862510
# 27381     81.6    13.3     4.9     37.5  ...      1.8      2.1     96.1  73.820880
# 27382     87.4     0.0    12.4     23.0  ...      0.0      4.0     96.1  66.592029
# ...        ...     ...     ...      ...  ...      ...      ...      ...        ...
# 644661    79.3    11.8     8.9     50.4  ...      1.2      7.5     91.3  61.115414
# 644682    35.9     6.7    52.4     84.3  ...      0.2      5.8     94.0  74.199530
# 644683    57.2    17.1    25.4     61.0  ...      0.8      7.6     91.6  67.685371
# 644687    73.2     8.1    18.7     56.9  ...      0.5      9.5     90.0  65.852932
# ...

# %%
count = 0
for i in list(OUT.columns) :
  print(count, " : ", i)
  count+=1
# Out:
# 0  :  BF_RUD
# 1  :  BF_INT
# 2  :  BF_ADV
# 3  :  CHH_RUD
# 4  :  CHH_INT
# 5  :  CHH_ADV
# 6  :  FC_RUD
# 7  :  FC_INT
# 8  :  FC_ADV
# 9  :  MSW_RUD
# 10  :  MSW_INT
# 11  :  MSW_ADV
# 12  :  TV
# 13  :  Tele
# 14  :  2w
# 15  :  4w
# 16  :  MSL_RUD
# 17  :  MSL_INT
# 18  :  MSL_ADV
# 19  :  LIT

# %% [markdown]
# <font color="red" size="5">Change the value of t in the below cell depending on the regression model you are training</font>

# %%
# LOAD THE INPUT AND REGRESSION OUTPUT

# IN = sys.argv[1]
# OUT = sys.argv[2]
# model_output_path = argv[3]

#Enter t = index for columns in OUT
# t = sys.argv[4]

model_name_dict = {0 : 'BF_RUD', 1 : 'BF_INT', 2 : 'BF_ADV', 6 : 'FC_RUD', 7 : 'FC_INT', 
     8 : 'FC_ADV', 9 : 'MSW_RUD', 10 : 'MSW_INT', 11 : 'MSW_ADV', 12 : 'TV', 13 : 'Tele', 14 : '2w', 15 : '4w', 16 : 'MSL_RUD', 17 : 'MSL_INT', 18 : 'MSL_ADV', 19 : 'LIT'}

t = 19

# %%
model_output_path = '/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Models/2011_Household_Indicators_Regression/viirs_models'
model_output_path
# Out:
# '/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Models/2011_Household_Indicators_Regression/viirs_models'

# %%
original_test_data = list(fc_val.keys())
X_test_append = IN.copy().filter(items = original_test_data, axis = 0)
print(len(X_test_append))
outliers_reqd = 68191 - len(X_test_append)
print(outliers_reqd)
X_test_append
# Out:
# 67623
# 568
#           BF_0_OUT_1    BF_0_OUT_2  BF_0_OUT_3  ...  sqrt_pop    log_hh   sqrt_hh
# 98228.0     0.598467  4.013616e-01    0.000172  ... -0.792536 -0.758541 -0.829053
# 221992.0    0.999985  5.186024e-11    0.000015  ...  3.801083  2.229063  3.844544
# 134768.0    0.999692  3.784210e-07    0.000308  ... -0.302222 -0.130935 -0.361381
# 425298.0    0.195443  6.975694e-01    0.106988  ... -1.255013 -1.225905 -1.087351
# 432229.0    0.720067  2.770243e-01    0.002909  ...  0.039227  0.400655  0.180190
# ...              ...           ...         ...  ...       ...       ...       ...
# 587760.0    0.000506  6.758856e-07    0.999494  ...  2.419534  2.095463  3.437496
# 545693.0    0.828105  1.690740e-01    0.002821  ... -0.454967 -0.186494 -0.409493
# 131993.0    0.975926  1.749633e-02    0.006578  ... -1.124933 -1.497893 -1.210164
# 520222.0    0.977156  2.169391e-02    0.001150  ... -0.585892 -0.287244 -0.493127
# ...

# %%
X_test = IN.copy().filter(items = outliers, axis=0)
X_test = X_test.copy().sample(n=outliers_reqd, random_state=1)
X_test
# len(original_test_data)
# Out:
#         BF_0_OUT_1  BF_0_OUT_2  BF_0_OUT_3  ...  sqrt_pop    log_hh   sqrt_hh
# 600616    0.993812    0.000021    0.006168  ... -0.930675 -1.187457 -1.068484
# 528735    0.934126    0.007631    0.058243  ... -1.788874 -4.138615 -1.798607
# 126952    0.987398    0.001307    0.011295  ... -1.036978 -1.206480 -1.077868
# 430007    0.996554    0.000046    0.003400  ... -1.088321 -1.016110 -0.979451
# 476319    0.974811    0.002020    0.023169  ... -1.671456 -3.125014 -1.663285
# ...            ...         ...         ...  ...       ...       ...       ...
# 424640    0.004691    0.990883    0.004426  ... -1.225387 -1.187457 -1.068484
# 424558    0.917835    0.004623    0.077542  ... -1.402851 -1.885258 -1.356592
# 241266    0.997840    0.001458    0.000702  ... -1.726503 -3.293227 -1.691181
# 522964    0.003059    0.000035    0.996907  ...  0.196360  0.637002  0.475850
# 258001    0.626482    0.280820    0.092698  ... -0.741346 -1.307969 -1.126331
#
# [568 rows x 132 columns]

# %%
intersect_val_outliers = set(X_test.index).intersection(X_test_append.index)
if len(intersect_val_outliers) == 0:
  X_test = X_test.append(X_test_append)
else :
  print("RETRYYYY")

# %%
X_test
# Out:
#           BF_0_OUT_1    BF_0_OUT_2  BF_0_OUT_3  ...  sqrt_pop    log_hh   sqrt_hh
# 600616.0    0.993812  2.051098e-05    0.006168  ... -0.930675 -1.187457 -1.068484
# 528735.0    0.934126  7.631068e-03    0.058243  ... -1.788874 -4.138615 -1.798607
# 126952.0    0.987398  1.307372e-03    0.011295  ... -1.036978 -1.206480 -1.077868
# 430007.0    0.996554  4.604984e-05    0.003400  ... -1.088321 -1.016110 -0.979451
# 476319.0    0.974811  2.020482e-03    0.023169  ... -1.671456 -3.125014 -1.663285
# ...              ...           ...         ...  ...       ...       ...       ...
# 587760.0    0.000506  6.758856e-07    0.999494  ...  2.419534  2.095463  3.437496
# 545693.0    0.828105  1.690740e-01    0.002821  ... -0.454967 -0.186494 -0.409493
# 131993.0    0.975926  1.749633e-02    0.006578  ... -1.124933 -1.497893 -1.210164
# 520222.0    0.977156  2.169391e-02    0.001150  ... -0.585892 -0.287244 -0.493127
# ...

# %%
X_train = IN.copy().drop(X_test.copy().index)
X_train
# Out:
#         BF_0_OUT_1  BF_0_OUT_2  BF_0_OUT_3  ...  sqrt_pop    log_hh   sqrt_hh
# 27379     0.020868    0.978828    0.000304  ... -0.359097 -0.056165 -0.294303
# 27380     0.162426    0.836869    0.000704  ...  0.916267  0.975670  0.971300
# 27381     0.047692    0.879542    0.072766  ...  0.536375  0.692629  0.551118
# 27382     0.764473    0.017324    0.218203  ...  0.756620  0.707235  0.571260
# 27384     0.107805    0.005368    0.886828  ... -0.498447 -0.212304 -0.431354
# ...            ...         ...         ...  ...       ...       ...       ...
# 644658    0.996187    0.000027    0.003786  ...  0.071295  0.843920  0.767685
# 644661    0.003038    0.996960    0.000002  ...  0.102866  0.833448  0.752116
# 644682    0.020880    0.000908    0.978212  ...  3.220821  2.376310  4.328670
# 644683    0.015891    0.014879    0.969230  ...  1.676138  1.847751  2.756499
# 644693    0.999980    0.000012    0.000008  ...  2.546358  2.177037  3.682520
#
# [272762 rows x 132 columns]

# %%
Y=OUT.copy()
Y = Y.iloc[:, t].astype('float64')
Y_train = Y.filter(items = X_train.index, axis = 0)
Y_test = Y.filter(items = X_test.index, axis = 0)
Y_test
# Out:
# 600616.0     4.615385
# 528735.0    90.000000
# 126952.0    88.549618
# 430007.0    12.393162
# 476319.0     3.703704
#               ...
# 587760.0    72.134831
# 545693.0    63.768116
# 131993.0    61.860465
# 520222.0    62.847222
# 380288.0    63.400576
# Name: LIT, Length: 68191, dtype: float64

# %%
intersect_train_test = set(X_train.index).intersection(X_test.index)
intersect_train_test
# Out:
# set()

# %%
# X, Y = IN.copy(), OUT.copy()



# # TRAIN-TEST SPLIT
# Y = Y.iloc[:, t].astype('float64')
# X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size=0.8, random_state=0)
print(len(X_train), len(X_test))
# Out:
# 272762 68191

# %% [markdown]
# <font color="red" size="5">Run only once to save test dataframe</font>

# %%
# pickle.dump(X_train, open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/pretraining_data/2nd_level_Regression_Test_and_Train_data_LitMsl/X_train.pickle', 'wb'))
pickle.dump(X_test, open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/pretraining_data/2nd_level_Regression_Test_and_Train_data_LitMsl/viirs_test_list/X_test_lit.pickle', 'wb'))
# pickle.dump(Y_train, open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/pretraining_data/2nd_level_Regression_Test_and_Train_data_LitMsl/Y_train.pickle', 'wb'))
pickle.dump(Y_test, open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/pretraining_data/2nd_level_Regression_Test_and_Train_data_LitMsl/viirs_test_list/Y_test_lit.pickle', 'wb'))

# %%
X_test2 = pickle.load(open('/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/pretraining_data/2nd_level_Regression_Test_and_Train_data_LitMsl/viirs_test_list/X_test_lit.pickle', 'rb'))
X_test.equals(X_test2)
# Out:
# True

# %% [markdown]
# ##<font color="red" size="5">Run only one of the below 2 cells (either run "identifying best feature for this model" or "For selecting common best features"</font>

# %% [markdown]
# #For identifying best features for this model

# %%
# n_estimators = 80
# max_features = 'sqrt'
# min_samples_split = 2
# max_samples = 0.7
# oob_score = True
# n_jobs = -1
# random_state = 0
# # max_depth = 2/4
# min_samples_leaf = 2
# # bootstrap = True

# %%
n_estimators = 50
max_features = 'sqrt'
min_samples_split = 2
max_samples = 0.7
oob_score = True
n_jobs = -1
random_state = 0
# max_depth = 2/4
min_samples_leaf = 2
# bootstrap = True

# %%
param_grid = {'n_estimators' : n_estimators,
              'max_features' : max_features,
              'min_samples_split' : min_samples_split,
              'max_samples' : max_samples,
              'oob_score' : oob_score,
              'n_jobs' : n_jobs,
              'random_state' : random_state,
              'min_samples_leaf' : min_samples_leaf}

# %%
def random_forest_features(X_train, Y_train, param_grid):
  sel = RandomForestRegressor(n_estimators=param_grid['n_estimators'], 
                              max_features=param_grid['max_features'], 
                              min_samples_split=param_grid['min_samples_split'],
                              max_samples=param_grid['max_samples'], 
                              oob_score=param_grid['oob_score'], 
                              n_jobs=param_grid['n_jobs'], 
                              random_state=param_grid['random_state'])
  sel.fit(X_train, Y_train)
  return sel.feature_importances_

# %%
cols = random_forest_features(X_train, Y_train, param_grid)
len(cols)
# Out:
# 132

# %%
cols
# Out:
# array([0.00576632, 0.00553726, 0.00553103, 0.0059233 , 0.00671491,
#        0.00565887, 0.00706968, 0.00637053, 0.00707195, 0.00649032,
#        0.00576936, 0.00579017, 0.00603533, 0.00610172, 0.00648881,
#        0.005633  , 0.00551672, 0.00554845, 0.00589353, 0.00673537,
#        0.00552549, 0.00674379, 0.00625427, 0.00775895, 0.0057555 ,
#        0.00552942, 0.0059569 , 0.00621343, 0.00591807, 0.00610262,
#        0.00571791, 0.00542487, 0.00567239, 0.00619952, 0.00697383,
#        0.00579812, 0.00700791, 0.00631996, 0.00673605, 0.005877  ,
#        0.00565433, 0.00572674, 0.00625441, 0.00615087, 0.00668837,
#        0.00554082, 0.00538224, 0.00540893, 0.00588119, 0.00722197,
#        0.00564746, 0.00725774, 0.00638686, 0.00704998, 0.00585051,
#        0.00568898, 0.0056258 , 0.00618425, 0.0060744 , 0.00636579,
#        0.00548024, 0.00556214, 0.00555122, 0.00603892, 0.00678176,
#        0.00548131, 0.00678384, 0.0066709 , 0.00731244, 0.00643772,
# ...

# %%
cnames = IN.columns.copy()
sids = cols.argsort()[::-1]
colsorted, cnames = cols[sids], cnames[sids]

thresh = np.mean(colsorted)
ids = np.argsort(cols)[::-1][:40]
print(ids)
# Out:
# [115 111 107 114 106 110 122 119  98 125 120 123 117 108  97 116 112  99
#   96  94 101 105 113 104  93 109 102  95 103  90 100  23  91  92  68  51
#   49   8   6  83]

# %%
# d = cols.copy()
# np.sort(d)[::-1]
# colsorted, cnames = cols[sids], cnames[sids]
cnames[:40], colsorted[:40]
# Out:
# (Index(['dc_score_sqrt_size_intensity', 'dc_score_log_size_intensity',
#         'dc_score_none_size_intensity', 'dc_score_sqrt_size',
#         'dc_score_none_size', 'dc_score_log_size',
#         'dc_score_log_intensity_only', 'dc_score_none_intensity_only',
#         'MSW_N_OUT_3', 'dc_score_sqrt_intensity_only', 'dc_score_log_size_only',
#         'dc_score_sqrt_size_only', 'dc_score_none_size_only',
#         'dc_score_none_intensity', 'MSW_N_OUT_2', 'dc_score_sqrt_intensity',
#         'dc_score_log_intensity', 'ASSET_N_OUT_1', 'MSW_N_OUT_1', 'FC_N_OUT_2',
#         'ASSET_N_OUT_3', 'dc_score_none_none', 'dc_score_sqrt_none',
#         'LIT_N_OUT_3', 'FC_N_OUT_1', 'dc_score_log_none', 'LIT_N_OUT_1',
#         'FC_N_OUT_3', 'LIT_N_OUT_2', 'BF_N_OUT_1', 'ASSET_N_OUT_2',
#         'MSW_1_OUT_3', 'BF_N_OUT_2', 'BF_N_OUT_3', 'MSW_4_OUT_3', 'MSW_3_OUT_1',
#         'FC_3_OUT_2', 'MSW_0_OUT_3', 'MSW_0_OUT_1', 'MSW_5_OUT_3'],
#        dtype='object'),
# ...

# %%
# cnames = IN.columns.copy()
# sids = cols.argsort()[::-1]
# colsorted, cnames = cols[sids], cnames[sids]

# thresh = np.mean(colsorted)
# # ids = np.where(colsorted >= thresh)[0]
# ids = np.argsort(cols)[::-1][:40]
# print(cnames[ids])
# print(colsorted[ids])

# %%
# np.sum(colsorted[ids][1:])
np.sum(colsorted[:40][1:])

# print(len(ids))
# ids
# Out:
# 0.5893909921786866

# %%
cnames[:14]
# Out:
# Index(['MSW_0_OUT_1', 'MSW_N_OUT_1', 'MSW_0_OUT_2', 'MSW_0_OUT_3',
#        'MSW_1_OUT_1', 'MSW_3_OUT_1', 'MSW_2_OUT_1', 'MSW_4_OUT_1',
#        'MSW_5_OUT_1', 'MSW_N_OUT_2', 'MSW_1_OUT_3', 'MSW_4_OUT_2',
#        'MSW_1_OUT_2', 'MSW_N_OUT_3'],
#       dtype='object')

# %% [markdown]
# # For Selecting common best features

# %%
#For MSW, ASSET, FC
# cols_best = ['dc_score_log_size_intensity',
#  'dc_score_none_size_intensity',
#  'dc_score_sqrt_size_intensity',
#  'dc_score_log_size',
#  'dc_score_sqrt_size',
#  'dc_score_none_size',
#  'MSW_N_OUT_2',
#  'MSW_N_OUT_1',
#  'MSW_N_OUT_3',
#  'FC_N_OUT_2',
#  'FC_N_OUT_1',
#  'dc_score_none_intensity',
#  'dc_score_sqrt_intensity',
#  'dc_score_log_intensity',
#  'ASSET_N_OUT_2',
#  'BF_N_OUT_1',
#  'ASSET_N_OUT_1',
#  'MSW_0_OUT_1',
#  'MSW_3_OUT_1',
#  'BF_N_OUT_2',
#  'MSW_2_OUT_1',
#  'MSW_5_OUT_2',
#  'MSW_0_OUT_2',
#  'ASSET_N_OUT_3',
#  'MSW_5_OUT_1',
#  'FC_0_OUT_2',
#  'MSW_4_OUT_2', 
#   'dc_score_none_intensity_only',
#  'dc_score_log_intensity_only',
#  'dc_score_sqrt_intensity_only',
#  'dc_score_none_size_only',
#  'dc_score_sqrt_size_only',
#  'dc_score_log_size_only',
#  'dc_score_sqrt_size_intensity_only',
#  'dc_score_log_size_intensity_only',
#  'dc_score_none_size_intensity_only']



# cols_best = ['FC_0_OUT_3', 'ASSET_4_OUT_3', 'MSW_N_OUT_3', 'dc_score_log_size_intensity', 'dc_score_sqrt_intensity_only', 'FC_N_OUT_1', 'dc_score_log_size_only', 'dc_score_sqrt_size_intensity', 'FC_N_OUT_2', 'dc_score_sqrt_size_only',  'FC_0_OUT_1', 'MSW_N_OUT_2', 'dc_score_log_intensity_only', 'ASSET_3_OUT_3', 'dc_score_none_size_only', 'ASSET_0_OUT_1', 'dc_score_log_size_intensity_only', 'MSW_0_OUT_3', 'dc_score_none_intensity_only', 'MSW_0_OUT_2']


#For BF
# cols_best = ['FC_0_OUT_3', 'ASSET_4_OUT_3', 'MSW_N_OUT_3', 'dc_score_log_size_intensity', 'dc_score_sqrt_intensity_only', 'FC_N_OUT_1', 'dc_score_log_size_only', 'dc_score_sqrt_size_intensity', 'FC_N_OUT_2', 'dc_score_sqrt_size_only',  'FC_0_OUT_1', 'MSW_N_OUT_2', 'dc_score_log_intensity_only', 'ASSET_3_OUT_3', 'dc_score_none_size_only', 'ASSET_0_OUT_1', 'dc_score_log_size_intensity_only', 'MSW_0_OUT_3', 'dc_score_none_intensity_only', 'MSW_0_OUT_2'
# ,'BF_0_OUT_1', 'BF_0_OUT_2', 'BF_0_OUT_3', 'BF_N_OUT_1', 'BF_N_OUT_2', 'BF_N_OUT_3']

# cols_best = cols_best = ['dc_score_sqrt_size_intensity', 'dc_score_log_size_intensity',
#        'dc_score_none_size_intensity', 'dc_score_none_size_intensity_only',
#        'dc_score_log_size', 'dc_score_sqrt_size_intensity_only',
#        'dc_score_sqrt_size_only', 'dc_score_sqrt_size',
#        'dc_score_none_size_only', 'dc_score_log_size_only',
#        'dc_score_none_size', 'dc_score_log_size_intensity_only', 'MSW_N_OUT_2',
#        'MSW_N_OUT_1', 'FC_N_OUT_1', 'ASSET_N_OUT_1',
#        'dc_score_none_intensity_only', 'MSW_N_OUT_3',
#        'dc_score_sqrt_intensity_only', 'FC_N_OUT_2',
#        'dc_score_log_intensity_only', 'ASSET_N_OUT_2',
#        'dc_score_none_intensity', 'dc_score_sqrt_intensity', 'BF_N_OUT_1']

# cols_best = ['dc_score_sqrt_size_intensity', 'dc_score_log_size_intensity',
#        'dc_score_none_size_intensity', 'dc_score_none_size',
#        'dc_score_sqrt_size', 'dc_score_log_size', 'dc_score_none_size_only',
#        'dc_score_sqrt_size_intensity_only', 'dc_score_log_size_only',
#        'dc_score_sqrt_size_only', 'dc_score_none_size_intensity_only',
#        'MSW_N_OUT_2', 'dc_score_log_size_intensity_only', 'MSW_N_OUT_1',
#        'MSW_N_OUT_3', 'FC_N_OUT_1', 'FC_N_OUT_2',
#        'dc_score_none_intensity_only', 'ASSET_N_OUT_2',
#        'dc_score_sqrt_intensity_only', 'dc_score_log_intensity_only',
#        'dc_score_log_intensity', 'ASSET_N_OUT_1', 'dc_score_none_intensity',
#        'dc_score_sqrt_intensity', 'BF_N_OUT_1', 'LIT_N_OUT_2', 'LIT_N_OUT_3',
#        'MSW_0_OUT_1']

cols_best = ['log_hh', 'sqrt_hh', 'hh', 'log_pop', 'sqrt_pop', 'pop', 'MSW_N_OUT_3',
       'MSW_0_OUT_3', 'ASSET_N_OUT_3', 'MSW_N_OUT_2', 'FC_N_OUT_2',
       'dc_score_sqrt_size_intensity_only',
       'dc_score_none_size_intensity_only', 'dc_score_log_size_intensity_only',
       'MSW_4_OUT_3', 'MSW_0_OUT_2', 'MSW_1_OUT_3', 'LIT_N_OUT_3',
       'dc_score_none_size_only', 'dc_score_log_size_intensity',
       'dc_score_sqrt_size_intensity', 'dc_score_none_size_intensity',
       'MSW_N_OUT_1', 'FC_0_OUT_2', 'MSW_5_OUT_3', 'dc_score_sqrt_size_only',
       'dc_score_log_size_only', 'FC_3_OUT_2', 'ASSET_N_OUT_1',
       'dc_score_sqrt_size', 'MSW_2_OUT_3', 'dc_score_log_size', 'FC_1_OUT_2',
       'MSW_3_OUT_3', 'dc_score_none_size', 'MSW_5_OUT_2']


print(len(cols_best))
# Out:
# 36

# %%
cnames_list = cols_best
print(cnames_list)
len(cnames_list)
# Out:
# ['log_hh', 'sqrt_hh', 'hh', 'log_pop', 'sqrt_pop', 'pop', 'MSW_N_OUT_3', 'MSW_0_OUT_3', 'ASSET_N_OUT_3', 'MSW_N_OUT_2', 'FC_N_OUT_2', 'dc_score_sqrt_size_intensity_only', 'dc_score_none_size_intensity_only', 'dc_score_log_size_intensity_only', 'MSW_4_OUT_3', 'MSW_0_OUT_2', 'MSW_1_OUT_3', 'LIT_N_OUT_3', 'dc_score_none_size_only', 'dc_score_log_size_intensity', 'dc_score_sqrt_size_intensity', 'dc_score_none_size_intensity', 'MSW_N_OUT_1', 'FC_0_OUT_2', 'MSW_5_OUT_3', 'dc_score_sqrt_size_only', 'dc_score_log_size_only', 'FC_3_OUT_2', 'ASSET_N_OUT_1', 'dc_score_sqrt_size', 'MSW_2_OUT_3', 'dc_score_log_size', 'FC_1_OUT_2', 'MSW_3_OUT_3', 'dc_score_none_size', 'MSW_5_OUT_2']
# 36

# %%
X_test.loc[:, cols_best]
# Out:
#             log_hh   sqrt_hh  ...  dc_score_none_size  MSW_5_OUT_2
# 600616.0 -1.187457 -1.068484  ...           -0.017339     0.087983
# 528735.0 -4.138615 -1.798607  ...           -0.439905     0.417428
# 126952.0 -1.206480 -1.077868  ...            0.269687     0.924421
# 430007.0 -1.016110 -0.979451  ...           -0.520656     0.282236
# 476319.0 -3.125014 -1.663285  ...            1.840469     0.522521
# ...            ...       ...  ...                 ...          ...
# 587760.0  2.095463  3.437496  ...           -0.427570     0.056088
# 545693.0 -0.186494 -0.409493  ...            0.315646     0.370605
# 131993.0 -1.497893 -1.210164  ...            0.264649     0.800676
# 520222.0 -0.287244 -0.493127  ...           -0.208429     0.077025
# 380288.0 -0.679249 -0.778365  ...           -0.598365     0.813515
#
# [68191 rows x 36 columns]

# %%
col_test = list(X_test.loc[:, cols_best].columns)
set([x for x in col_test if col_test.count(x) > 1])
# Out:
# set()

# %% [markdown]
# #finalize train and test df

# %%
#If best feature for that model is selected
# X_train_final, X_test_final = X_train.iloc[:, ids], X_test.iloc[:, ids]

#If common best feature is selected
X_train_final, X_test_final = X_train.loc[:, cols_best], X_test.loc[:, cols_best]

X_train_final.shape, X_test_final.shape
# Out:
# ((272762, 36), (68191, 36))

# %% [markdown]
# # Train Model

# %%
# n_estimators = [20, 40, 80]
# max_features = ['log2', 'sqrt']
# min_samples_split = [0.01, 0.5, 2, 5]
# max_samples = [0.7, 0.6]
# oob_score = [True, False]
# n_jobs = [-1]
# random_state = [0]
# min_samples_leaf = [1, 2]

# n_estimators = [80]
# max_features = ['sqrt']
# min_samples_split = [2]
# max_samples = [0.7]
# oob_score = [True]
# n_jobs = [-1]
# random_state = [0]
# min_samples_leaf = [2]

# %% [markdown]
# <font color="red" size="5">Parameters used</font>

# %%
n_estimators = [80]
max_features = ['sqrt']
min_samples_split = [75]
# min_samples_leaf = [5]
max_samples = [0.7]
oob_score = [True]
n_jobs = [-1]
random_state = [0]

# %%
param_grid = {'n_estimators' : n_estimators,
              'max_features' : max_features,
              'min_samples_split' : min_samples_split,
              'max_samples' : max_samples,
              'oob_score' : oob_score,
              'n_jobs' : n_jobs,
              'random_state' : random_state, 
              # 'min_samples_leaf' : min_samples_leaf
              }

# %%
regressor = RandomForestRegressor()

# %%
from sklearn.model_selection import GridSearchCV
rf_Grid = GridSearchCV(estimator = regressor, param_grid = param_grid, cv = 3, verbose=2, n_jobs = -1)

# %%
rf_Grid.fit(X_train_final, Y_train)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'max_features': ['sqrt'], 'max_samples': [0.7],
#                          'min_samples_split': [75], 'n_estimators': [80],
#                          'n_jobs': [-1], 'oob_score': [True],
#                          'random_state': [0]},
#              verbose=2)

# %%
X_test_final.columns
# Out:
# Index(['log_hh', 'sqrt_hh', 'hh', 'log_pop', 'sqrt_pop', 'pop', 'MSW_N_OUT_3',
#        'MSW_0_OUT_3', 'ASSET_N_OUT_3', 'MSW_N_OUT_2', 'FC_N_OUT_2',
#        'dc_score_sqrt_size_intensity_only',
#        'dc_score_none_size_intensity_only', 'dc_score_log_size_intensity_only',
#        'MSW_4_OUT_3', 'MSW_0_OUT_2', 'MSW_1_OUT_3', 'LIT_N_OUT_3',
#        'dc_score_none_size_only', 'dc_score_log_size_intensity',
#        'dc_score_sqrt_size_intensity', 'dc_score_none_size_intensity',
#        'MSW_N_OUT_1', 'FC_0_OUT_2', 'MSW_5_OUT_3', 'dc_score_sqrt_size_only',
#        'dc_score_log_size_only', 'FC_3_OUT_2', 'ASSET_N_OUT_1',
#        'dc_score_sqrt_size', 'MSW_2_OUT_3', 'dc_score_log_size', 'FC_1_OUT_2',
#        'MSW_3_OUT_3', 'dc_score_none_size', 'MSW_5_OUT_2'],
#       dtype='object')

# %%
print(rf_Grid.score(X_train_final, Y_train))
# Out:
# 0.6366965187924438

# %%
#R2 SCORE ON TEST DATA
print(rf_Grid.score(X_test_final.iloc[:15000,:], Y_test.iloc[:15000]))
rf_Grid.score(X_test_final, Y_test)
# Out:
# -0.053587471090923655
# 0.537052207914537

# %%
best_param_dict = rf_Grid.best_params_
best_param_dict
# Out:
# {'max_features': 'sqrt',
#  'max_samples': 0.7,
#  'min_samples_split': 75,
#  'n_estimators': 80,
#  'n_jobs': -1,
#  'oob_score': True,
#  'random_state': 0}

# %%
scores_dict = {}
scores_dict['train_score'] = rf_Grid.score(X_train_final, Y_train)
scores_dict['test_score'] = rf_Grid.score(X_test_final, Y_test)
scores_dict
# Out:
# {'test_score': 0.537052207914537, 'train_score': 0.6366965187924438}

# %%
best_param_and_imp_features_dict = {}
best_param_and_imp_features_dict['imp_columns'] = cnames_list
# best_param_and_imp_features_dict['score_imp_columns'] = cnames_score_list
best_param_and_imp_features_dict['best_params'] = best_param_dict
best_param_and_imp_features_dict['scores'] = scores_dict
# best_param_and_imp_features_dict

# %%
rf_Grid.predict(X_test_final)
# Out:
# array([41.79105759, 60.77728844, 60.7626504 , ..., 50.84774995,
#        63.72908692, 63.40932793])

# %% [markdown]
# #SAVE MODEL AND PARAMETERS

# %%
final_model = os.path.join(model_output_path, model_name_dict[t].lower()+'_reg')
final_model
# Out:
# '/content/drive/MyDrive/Scripts_and_Data_Transfer/3.Arch_2_Procedure/5.Train_Regression_and_Classification_Models/Models/2011_Household_Indicators_Regression/viirs_models/lit_reg'

# %%
params_best_old = pickle.load(open(final_model+'_BestParams_ImpFeatures_R2scores.pickle','rb'))
params_best_old
# Out:
# {'best_params': {'max_features': 'sqrt',
#   'max_samples': 0.7,
#   'min_samples_split': 75,
#   'n_estimators': 80,
#   'n_jobs': -1,
#   'oob_score': True,
#   'random_state': 0},
#  'imp_columns': ['dc_score_sqrt_size_intensity',
#   'dc_score_log_size_intensity',
#   'dc_score_none_size_intensity',
#   'dc_score_none_size',
#   'dc_score_sqrt_size',
#   'dc_score_log_size',
#   'dc_score_none_size_only',
#   'dc_score_sqrt_size_intensity_only',
#   'dc_score_log_size_only',
#   'dc_score_sqrt_size_only',
#   'dc_score_none_size_intensity_only',
#   'MSW_N_OUT_2',
#   'dc_score_log_size_intensity_only',
#   'MSW_N_OUT_1',
#   'MSW_N_OUT_3',
#   'FC_N_OUT_1',
#   'FC_N_OUT_2',
#   'dc_score_none_intensity_only',
#   'ASSET_N_OUT_2',
#   'dc_score_sqrt_intensity_only',
#   'dc_score_log_intensity_only',
#   'dc_score_log_intensity',
#   'ASSET_N_OUT_1',
#   'dc_score_none_intensity',
#   'dc_score_sqrt_intensity',
#   'BF_N_OUT_1',
#   'LIT_N_OUT_2',
#   'LIT_N_OUT_3',
# ...

# %%
pickle.dump(rf_Grid, open(final_model+'.pickle','wb'))
pickle.dump(best_param_and_imp_features_dict, open(final_model+'_BestParams_ImpFeatures_R2scores.pickle','wb'))

# %% [markdown]
# #Finding Best Features

# %%
# primary_school = [0.00334564, 0.00280631, 0.00341592, 0.00506313, 0.00688205,
#        0.00377601, 0.0048306 , 0.00401126, 0.00360667, 0.00681599,
#        0.00528252, 0.00365303, 0.00415873, 0.00496573, 0.00486564,
#        0.00502485, 0.00248923, 0.00395583, 0.00616848, 0.00430678,
#        0.00381536, 0.00475405, 0.00503652, 0.00338448, 0.00424819,
#        0.00437274, 0.00357365, 0.00368533, 0.00450895, 0.00434498,
#        0.00439127, 0.00344567, 0.00318731, 0.00635636, 0.00786556,
#        0.00471906, 0.00497242, 0.00637778, 0.00408023, 0.00578744,
#        0.00532246, 0.00516219, 0.00436288, 0.00466852, 0.00499204,
#        0.00572294, 0.00307907, 0.00337924, 0.00557435, 0.00572955,
#        0.00412344, 0.00509039, 0.00549812, 0.00407449, 0.00574577,
#        0.00524328, 0.00498718, 0.00408663, 0.00416939, 0.00432706,
#        0.00369143, 0.00318173, 0.00305844, 0.00461073, 0.0055093 ,
#        0.00412222, 0.0051674 , 0.00566628, 0.00464002, 0.0068432 ,
#        0.00427695, 0.00410729, 0.00369277, 0.00478786, 0.00484617,
#        0.00393108, 0.00357656, 0.00307172, 0.00418805, 0.00564761,
#        0.0038299 , 0.00451629, 0.00429636, 0.00528253, 0.00816973,
#        0.00510206, 0.0041197 , 0.00403934, 0.00437955, 0.00450389,
#        0.00771475, 0.00632326, 0.00694303, 0.01070076, 0.01180658,
#        0.00828528, 0.00940558, 0.01019416, 0.00817176, 0.01772748,
#        0.00940517, 0.00812832, 0.00480407, 0.00710329, 0.00810102,
#        0.00689748, 0.02219693, 0.03435989, 0.00994485, 0.00621129,
#        0.02794906, 0.0356117 , 0.01000177, 0.00727182, 0.02336182,
#        0.0334285 , 0.00919932, 0.02444828, 0.04549227, 0.01423298,
#        0.01893336, 0.0237481 , 0.0117306 , 0.02807281, 0.02784077,
#        0.01526912, 0.00255703, 0.00275045, 0.00233573, 0.00200641,
#        0.00253366, 0.00227258]

# middle_school = [0.00341581, 0.00315342, 0.00311198, 0.00426273, 0.00511261,
#        0.0035747 , 0.00376461, 0.01578749, 0.00452227, 0.00454263,
#        0.00434758, 0.00330946, 0.00352514, 0.00462486, 0.00394133,
#        0.00331205, 0.00295624, 0.00301215, 0.00393554, 0.00570852,
#        0.00436003, 0.00467575, 0.00731917, 0.00455255, 0.00419976,
#        0.00415091, 0.0032843 , 0.00389696, 0.00666889, 0.0038054 ,
#        0.00293488, 0.00322221, 0.00325802, 0.0045831 , 0.00623699,
#        0.00366761, 0.00502951, 0.01327699, 0.00424296, 0.00346655,
#        0.00454097, 0.0038015 , 0.00329349, 0.00503023, 0.00423   ,
#        0.00381733, 0.0036871 , 0.0028651 , 0.0048112 , 0.00574464,
#        0.00343616, 0.00458016, 0.01257053, 0.00472229, 0.00322317,
#        0.00453451, 0.00387984, 0.00395536, 0.00484421, 0.0038968 ,
#        0.00336797, 0.00248267, 0.00330916, 0.00427365, 0.0064939 ,
#        0.0034304 , 0.00414711, 0.01779809, 0.00493032, 0.00373921,
#        0.00450518, 0.00368448, 0.00485878, 0.0054853 , 0.00436848,
#        0.00355485, 0.00325008, 0.0036577 , 0.00525772, 0.00763317,
#        0.00308419, 0.00445028, 0.01273871, 0.0048918 , 0.00455908,
#        0.00448433, 0.00425869, 0.00463575, 0.00460986, 0.0046218 ,
#        0.00609273, 0.00640395, 0.00533405, 0.01123887, 0.01356564,
#        0.00569542, 0.01648493, 0.02864835, 0.01288534, 0.01093112,
#        0.00982411, 0.00547909, 0.00673915, 0.00925501, 0.00656757,
#        0.0063492 , 0.02643871, 0.02952701, 0.01081019, 0.00685092,
#        0.02968562, 0.03110166, 0.01030318, 0.00753777, 0.03372778,
#        0.03456684, 0.01059383, 0.02064451, 0.02670441, 0.01713841,
#        0.01889258, 0.01282426, 0.01478553, 0.01898815, 0.01863184,
#        0.01428883, 0.00222315, 0.00211894, 0.00234148, 0.00256053,
#        0.00213095, 0.00230743]

bus = [0.00185416, 0.00139516, 0.00119368, 0.00285607, 0.00365088,
       0.0015681 , 0.00539292, 0.00492724, 0.00491108, 0.00448624,
       0.00140488, 0.001607  , 0.00307729, 0.00206443, 0.00296934,
       0.00203648, 0.00147599, 0.00124318, 0.00170208, 0.00345798,
       0.00119153, 0.00471124, 0.0043312 , 0.00550503, 0.00137402,
       0.00172689, 0.00116573, 0.00221942, 0.00196278, 0.00367293,
       0.00158297, 0.00125246, 0.00129981, 0.00249219, 0.0046771 ,
       0.00211565, 0.00451309, 0.00611873, 0.0035411 , 0.00313578,
       0.00211828, 0.00142801, 0.00186444, 0.00162819, 0.00341372,
       0.00305609, 0.00113934, 0.00123328, 0.00373646, 0.0020862 ,
       0.00133343, 0.00495527, 0.00463841, 0.00322825, 0.00237698,
       0.00144134, 0.00155342, 0.00232106, 0.00155866, 0.0025785 ,
       0.00392002, 0.00135357, 0.00130081, 0.00320808, 0.00316782,
       0.00212634, 0.00440431, 0.00492258, 0.00411181, 0.00532005,
       0.00276167, 0.00151437, 0.00201823, 0.00254485, 0.00281274,
       0.00366684, 0.00134234, 0.00110632, 0.00258314, 0.00278164,
       0.00100423, 0.00311708, 0.00663106, 0.00580671, 0.00442391,
       0.00390977, 0.0010193 , 0.00216115, 0.00260443, 0.00322306,
       0.00736558, 0.00604294, 0.00447127, 0.01339058, 0.01078065,
       0.00574296, 0.01462563, 0.02451827, 0.01545501, 0.02269766,
       0.00985619, 0.00658272, 0.00682042, 0.00797909, 0.00873537,
       0.00322176, 0.01854254, 0.0429974 , 0.00675468, 0.00315864,
       0.03273631, 0.07692965, 0.00583496, 0.00368162, 0.02602899,
       0.06493573, 0.00715814, 0.03362011, 0.05815417, 0.01234108,
       0.02730298, 0.03294386, 0.01218503, 0.03979009, 0.05763742,
       0.01271527, 0.00093547, 0.00084869, 0.0009599 , 0.00097497,
       0.00116043, 0.00096441]

tele = [0.00274802, 0.00225195, 0.0011558 , 0.00741892, 0.00448434,
       0.00175992, 0.01276301, 0.00346367, 0.00359972, 0.00146876,
       0.00232607, 0.00159617, 0.00174289, 0.00274214, 0.00234039,
       0.00242687, 0.00216775, 0.00140748, 0.00497952, 0.00555631,
       0.00142084, 0.00757372, 0.00527774, 0.00424886, 0.00222565,
       0.00141293, 0.00271   , 0.00192051, 0.00188327, 0.00305286,
       0.00241704, 0.0021911 , 0.00150451, 0.00534364, 0.00421558,
       0.00251325, 0.00723685, 0.00274667, 0.00561322, 0.00125576,
       0.00167537, 0.00132101, 0.00153175, 0.00140421, 0.0023705 ,
       0.00279182, 0.0014945 , 0.00142031, 0.01019463, 0.00362814,
       0.00122904, 0.00673061, 0.00272885, 0.00611636, 0.00174065,
       0.00210289, 0.00189332, 0.00224901, 0.0022591 , 0.00207565,
       0.00282309, 0.00219804, 0.0012902 , 0.00381536, 0.00324394,
       0.00193752, 0.00695543, 0.00323834, 0.00584587, 0.00201849,
       0.00174249, 0.00198659, 0.00285384, 0.00178013, 0.00146885,
       0.00308834, 0.00214903, 0.00217456, 0.0114077 , 0.00483643,
       0.00194423, 0.00975913, 0.00484136, 0.01237853, 0.00180696,
       0.00200158, 0.00161573, 0.00207346, 0.00214148, 0.00250062,
       0.01361224, 0.00775942, 0.00583613, 0.03102778, 0.01587693,
       0.00676217, 0.03298166, 0.01902966, 0.020978  , 0.00838996,
       0.00914963, 0.01057881, 0.00732436, 0.00599279, 0.00963764,
       0.00402818, 0.02900031, 0.05672034, 0.00930385, 0.00266373,
       0.04340408, 0.04954749, 0.0069358 , 0.00315085, 0.02649927,
       0.06562681, 0.00794799, 0.0249255 , 0.01917908, 0.0154755 ,
       0.03267486, 0.0196741 , 0.01143631, 0.02873675, 0.01913523,
       0.01402167, 0.00093409, 0.00057498, 0.00090305, 0.00096595,
       0.0007699 , 0.00078839]

# %%
final_scores = []

for i in range(len(primary_school)) :
  final_scores.append(primary_school[i] + middle_school[i] + tele[i] + bus[i])

# %%
cnames = IN.columns.copy()
sids = np.array(final_scores).argsort()[::-1]
colsorted, cnames = cols[sids], cnames[sids]

cnames
# Out:
# Index(['dc_score_sqrt_size_intensity', 'dc_score_log_size_intensity',
#        'dc_score_none_size_intensity', 'dc_score_none_size_intensity_only',
#        'dc_score_sqrt_size_intensity_only', 'dc_score_log_size',
#        'dc_score_sqrt_size_only', 'dc_score_log_size_only',
#        'dc_score_none_size_only', 'dc_score_log_size_intensity_only',
#        ...
#        'FC_1_OUT_3', 'BF_4_OUT_3', 'FC_3_OUT_3', 'BF_0_OUT_3', 'sqrt_pop',
#        'log_hh', 'pop', 'log_pop', 'sqrt_hh', 'hh'],
#       dtype='object', length=132)

# %%
# a = [6, 7, 2, 3]
# np.array(a).argsort()[::-1]

# %%
print(len(colsorted))
thresh = sum(colsorted)/len(colsorted)
thresh
# Out:
# 132
# 0.007575757575757576

# %%
fin_ids = np.where(colsorted > thresh)[0]
len(fin_ids)
# Out:
# 24

# %%
print(colsorted)
# Out:
# [0.06493573 0.07692965 0.0429974  0.05815417 0.05763742 0.03273631
#  0.03979009 0.02730298 0.03362011 0.03294386 0.02602899 0.01462563
#  0.01854254 0.01339058 0.02451827 0.01545501 0.02269766 0.01234108
#  0.01271527 0.01078065 0.01218503 0.00736558 0.00985619 0.00873537
#  0.00580671 0.00539292 0.00658272 0.00675468 0.00715814 0.00682042
#  0.00258314 0.00797909 0.00373646 0.00604294 0.00311708 0.00583496
#  0.00574296 0.00471124 0.00451309 0.00495527 0.00663106 0.00440431
#  0.00447127 0.00285607 0.00411181 0.00550503 0.0043312  0.00322825
#  0.0035411  0.00345798 0.0046771  0.00611873 0.00491108 0.00492724
#  0.00492258 0.00365088 0.00249219 0.00278164 0.00463841 0.00532005
#  0.00322176 0.00320808 0.00368162 0.00366684 0.00392002 0.00367293
#  0.00170208 0.00316782 0.00442391 0.00448624 0.00390977 0.00305609
#  0.00315864 0.00341372 0.00322306 0.0020862  0.00296934 0.00201823
#  0.00307729 0.00206443 0.00260443 0.0025785  0.00211565 0.00185416
# ...

# %%
print(cnames[:25])
# Out:
# Index(['dc_score_sqrt_size_intensity', 'dc_score_log_size_intensity',
#        'dc_score_none_size_intensity', 'dc_score_none_size_intensity_only',
#        'dc_score_sqrt_size_intensity_only', 'dc_score_log_size',
#        'dc_score_sqrt_size_only', 'dc_score_log_size_only',
#        'dc_score_none_size_only', 'dc_score_log_size_intensity_only',
#        'dc_score_sqrt_size', 'MSW_N_OUT_1', 'dc_score_none_size', 'FC_N_OUT_1',
#        'MSW_N_OUT_2', 'MSW_N_OUT_3', 'ASSET_N_OUT_1',
#        'dc_score_none_intensity_only', 'dc_score_sqrt_intensity_only',
#        'FC_N_OUT_2', 'dc_score_log_intensity_only', 'BF_N_OUT_1',
#        'ASSET_N_OUT_2', 'LIT_N_OUT_3', 'MSW_5_OUT_3'],
#       dtype='object')

# %%
z = IN.iloc[:, list(sids)].columns

# %%
list(z)[:25]
# Out:
# ['dc_score_sqrt_size_intensity',
#  'dc_score_log_size_intensity',
#  'dc_score_none_size_intensity',
#  'dc_score_none_size_intensity_only',
#  'dc_score_sqrt_size_intensity_only',
#  'dc_score_log_size',
#  'dc_score_sqrt_size_only',
#  'dc_score_log_size_only',
#  'dc_score_none_size_only',
#  'dc_score_log_size_intensity_only',
#  'dc_score_sqrt_size',
#  'MSW_N_OUT_1',
#  'dc_score_none_size',
#  'FC_N_OUT_1',
#  'MSW_N_OUT_2',
#  'MSW_N_OUT_3',
#  'ASSET_N_OUT_1',
#  'dc_score_none_intensity_only',
#  'dc_score_sqrt_intensity_only',
#  'FC_N_OUT_2',
#  'dc_score_log_intensity_only',
#  'BF_N_OUT_1',
#  'ASSET_N_OUT_2',
#  'LIT_N_OUT_3',
#  'MSW_5_OUT_3']
